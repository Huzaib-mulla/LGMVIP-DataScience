# %% [markdown]
# # Author: Huzaib Mujeeb Mulla
# ## Let's Grow More - VIP Internship
# ### Task 2 - Image to Pencil Sketch with Python
# ##### Description --
#
# **We need to read the image in RBG format and then convert it to a grayscale image.This will turn an image into a classic black and white photo.\
# Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image.\
# Inversion can be used to enhance details. \
# Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image.\
# This can be done by dividing the grayscale image by the inverted blurry image.\
# Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.**

# %% [markdown]
# ### Importing Libraries

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# ### Read the Image

# %%
image = cv2.imread('bird.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=500x583 at 0x1FE2DE407F0>

# %% [markdown]
# ### Resize the Image

# %%
resized = cv2.resize(image,(350,400))
display(Image.fromarray(resized))
# Out:
# <PIL.Image.Image image mode=RGB size=350x400 at 0x1FE2F3D77C0>

# %% [markdown]
# ### Convert to Grayscale

# %%
grey_image = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(grey_image))
# Out:
# <PIL.Image.Image image mode=L size=350x400 at 0x1FE2F607EE0>

# %% [markdown]
# ### Convert to Negative Image

# %%
image_inv = cv2.bitwise_not(grey_image)
display(Image.fromarray(image_inv))
# Out:
# <PIL.Image.Image image mode=L size=350x400 at 0x1FE2F607940>

# %% [markdown]
# ### Finally a Pencil Sketch

# %%
inverted_image = 255 - grey_image
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(grey_image, inverted_blurred, scale=256.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=350x400 at 0x1FE2F6169D0>

# %%
cv2.imshow("original image", resized)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
